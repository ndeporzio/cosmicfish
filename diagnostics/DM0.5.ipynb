# %%
import os
import shutil
import numpy as np
import pandas as pd
import seaborn as sns 
import cosmicfish as cf 
import matplotlib.pyplot as plt
import dill


# Instruct pyplot to use seaborn 
sns.set()

# Set project, data, CLASS directories 
projectdir = cf.correct_path("/Volumes/SSD01/")
datastore = cf.correct_path("/Volumes/SSD01/data.nosync16b/")
classpath = os.path.join("/Users/nicholasdeporzio/Desktop/cfworkspace/class3")

# Specify resolution of numerical integrals
derivative_step = 0.008 # How much to vary parameter to calculate numerical derivative
mu_integral_step = 0.05 # For calculating numerical integral wrt mu between -1 and 1 

# Generate output paths  
ps16_resultsdir = os.path.join(projectdir, 'results', 'ps16b')
cf.makedirectory(ps16_resultsdir)

# Linda Fiducial Cosmology 
ps16_fid = {
        "A_s" : 2.2321e-9, 
        "n_s" : 0.967,
        "omega_b" : 0.02226,
        "omega_cdm" : 0.1127,
        "tau_reio" : 0.0598,
        "h" : 0.701,
        "T_cmb" : 2.726, # Units [K]
        "N_ncdm" : 1., 
        "deg_ncdm" : 1.5,
        "T_ncdm" : (0.9052/2.726), # Units [T_cmb]. 
        "m_ncdm" : 0.0328, # Units [eV]
        "b0" : 1.0, 
        "beta0" : 1.7, 
        "beta1" : 1.0,
        "alphak2" : 1.0,
        "sigma_fog_0" : 250000, #Units [m s^-2]
        "N_eff" : 3.046, #We allow relativistic neutrinos in addition to our DM relic
        "relic_vary" : "N_ncdm" # Fix T_ncdm or m_ncdm 
        }

# EUCLID Parameters
z_table = np.array([0.65, 0.75, 0.85, 0.95, 1.05, 1.15, 1.25, 1.35, 1.45, 1.55, 1.65, 1.75, 1.85, 1.95])
dNdz = np.array([2434.280, 4364.812, 4728.559, 4825.798, 4728.797, 4507.625, 4269.851, 3720.657, 3104.309, 
    2308.975, 1514.831, 1474.707, 893.716, 497.613])
skycover = 0.3636 # Sky coverage of survey in fraction

# Run Fisher Forecast
#masses = np.append(np.array([0.001, 0.01]), np.geomspace(0.1, 22.0, 25))
masses = np.array([0.2])

omegacdm_set = ps16_fid['omega_cdm'] - ps16_fid["N_ncdm"]*((masses/cf.NEUTRINO_SCALE_FACTOR)*np.power(ps16_fid['T_ncdm']*2.726 / 1.95, 3.))                                     
ps16_fiducialset = [dict(ps16_fid, **{'m_ncdm' : masses[midx], 'omega_cdm' : omegacdm_set[midx]}) 
               for midx, mval in enumerate(masses)]

# %%
ps16_forecastset = [cf.forecast(
    classpath, 
    datastore, 
    'relic', 
    fidval, 
    z_table, 
    "EUCLID",
    dNdz, 
    fsky=skycover, 
    dstep=derivative_step,
    RSD=True,
    FOG=True,
    AP=True,
    COV=True) for fididx, fidval in enumerate(ps16_fiducialset)]
for fidx, fcst in enumerate(ps16_forecastset): 
    fcst.gen_pm()
    fcst.gen_fisher(
        fisher_order=[
            'omega_b',                                    
            'omega_cdm',                                  
            'n_s',                                        
            'A_s',                                        
            'tau_reio',                                   
            'h',                                                                             
            'N_ncdm',                                 
            'sigma_fog',                                   
            'beta0',
            'beta1',
            'alpha_k2'],
        mu_step=mu_integral_step, 
        skipgen=False)
    print("Relic Forecast ", fidx, " complete...")
    dill.dump_session(os.path.join(ps16_resultsdir, 'ps16b.db'))
# Out:
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.65
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581953.42212820.369464
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.75
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581954.05752090.545478
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.85
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581954.6800420.571780
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.95
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581955.4068460.767387
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.05
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581956.0344170.384110
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.15
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581956.62338520.355517
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.25
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581957.3022560.410152
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.35
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581958.021120.424396
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.45
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581958.7398250.171001
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.55
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581959.6849680.101531
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.65
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581960.5306260.749473
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.75
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581961.2238520.271151
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.85
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581961.90956280.062269
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.95
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581962.6994180.414811
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02243808
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.65
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581963.39256020.293967
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02243808
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.75
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581964.0786990.503542
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02243808
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.85
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581964.9238070.919071
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02243808
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.95
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581965.7460640.585181
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02243808
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.05
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581966.4225360.874002
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02243808
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.15
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581967.2405860.398732
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02243808
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.25
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581968.07844610.390058
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02243808
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.35
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581968.82765480.161665
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02243808
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.45
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581969.80422620.995785
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02243808
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.55
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581970.928650.614387
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02243808
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.65
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581971.8501750.665994
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02243808
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.75
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581972.757920.251750
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02243808
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.85
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581973.62925220.234582
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02243808
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.95
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581975.285470.788733
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.022081919999999998
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.65
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581976.35636780.713090
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.022081919999999998
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.75
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581977.6037410.453569
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.022081919999999998
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.85
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581978.3535690.434457
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.022081919999999998
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.95
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581979.6347520.806814
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.022081919999999998
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.05
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581980.9257450.603113
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.022081919999999998
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.15
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581981.9598870.260136
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.022081919999999998
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.25
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581983.2053030.947729
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.022081919999999998
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.35
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581984.47650.818955
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.022081919999999998
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.45
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581985.333780.988151
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.022081919999999998
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.55
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581986.5680870.786194
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.022081919999999998
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.65
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581987.51657920.686483
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.022081919999999998
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.75
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581988.8420380.614312
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.022081919999999998
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.85
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581990.463640.782002
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.022081919999999998
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.95
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581991.65914490.256075
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.1133850869410217
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.65
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581992.493910.074494
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.1133850869410217
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.75
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581993.519240.400019
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.1133850869410217
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.85
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581994.6818580.143438
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.1133850869410217
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.95
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581995.9722770.013247
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.1133850869410217
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.05
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581997.3155470.417177
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.1133850869410217
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.15
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581998.33876780.425173
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.1133850869410217
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.25
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586581999.5667820.528047
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.1133850869410217
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.35
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582000.5499460.930391
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.1133850869410217
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.45
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582001.8273130.168449
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.1133850869410217
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.55
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582002.8068270.634341
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.1133850869410217
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.65
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582003.98281380.344359
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.1133850869410217
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.75
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582004.9593570.879413
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.1133850869410217
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.85
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582006.3713910.716984
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.1133850869410217
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.95
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582007.4100250.700294
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11158532365624357
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.65
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582008.70713190.272513
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11158532365624357
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.75
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582009.9131560.542265
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11158532365624357
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.85
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582011.3383040.499349
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11158532365624357
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.95
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582012.81759790.445391
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11158532365624357
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.05
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582014.3680740.731705
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11158532365624357
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.15
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582015.6853760.186002
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11158532365624357
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.25
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582017.2241870.924104
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11158532365624357
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.35
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582018.65152220.319130
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11158532365624357
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.45
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582020.0317380.543653
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11158532365624357
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.55
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582022.1919370.320757
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11158532365624357
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.65
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582023.8692330.931952
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11158532365624357
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.75
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582025.4703240.540324
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11158532365624357
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.85
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582027.0051580.799704
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11158532365624357
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.95
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582028.2365780.023089
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.706608
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.65
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582030.2574590.376479
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.706608
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.75
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582031.8534730.047942
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.706608
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.85
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582033.4998930.850604
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.706608
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.95
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582035.2920280.771356
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.706608
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.05
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582036.6852450.266755
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.706608
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.15
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582037.8174620.633594
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.706608
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.25
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582039.4550120.973387
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.706608
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.35
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582040.563810.780345
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.706608
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.45
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582042.4107640.913583
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.706608
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.55
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582044.04552820.562219
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.706608
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.65
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582045.9731620.299167
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.706608
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.75
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582047.1420050.557225
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.706608
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.85
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582048.45501690.172335
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.706608
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.95
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582049.7384610.507502
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.6953919999999999
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.65
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582051.4984190.012158
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.6953919999999999
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.75
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582053.12837820.951368
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.6953919999999999
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.85
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582054.8713180.006672
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.6953919999999999
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.95
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582056.380760.010690
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.6953919999999999
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.05
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582057.6919260.773071
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.6953919999999999
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.15
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582059.112150.239264
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.6953919999999999
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.25
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582060.5562430.284126
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.6953919999999999
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.35
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582061.7441350.168461
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.6953919999999999
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.45
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582062.8562630.477669
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.6953919999999999
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.55
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582064.5388580.835153
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.6953919999999999
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.65
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582065.5830830.624795
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.6953919999999999
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.75
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582067.28241680.448172
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.6953919999999999
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.85
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582068.6669740.660718
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.6953919999999999
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.95
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582070.3146110.842599
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0602784
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.65
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582071.8867090.898288
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0602784
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.75
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582073.2094830.720436
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0602784
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.85
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582074.374330.948192
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0602784
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.95
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582076.2197690.679751
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0602784
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.05
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582077.289920.857590
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0602784
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.15
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582078.94251590.677554
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0602784
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.25
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582080.53198310.061535
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0602784
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.35
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582082.2052760.375670
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0602784
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.45
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582083.2662850.816521
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0602784
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.55
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582084.4715240.093883
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0602784
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.65
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582085.43305180.322916
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0602784
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.75
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582086.4232010.135372
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0602784
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.85
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582087.74940010.936140
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0602784
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.95
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582089.27786180.004652
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.059321599999999995
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.65
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582090.53244690.944184
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.059321599999999995
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# ...
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.85
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582104.9244450.392979
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.059321599999999995
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.5
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.95
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582106.3398610.702272
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.512
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.65
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582107.77991820.428078
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.512
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.75
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582108.9112450.054479
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.512
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.85
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582110.0402230.943885
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.512
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.95
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582110.9805630.378043
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.512
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.05
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582112.0488620.948960
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.512
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.15
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582113.2885270.657606
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.512
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.25
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582114.77698780.161657
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.512
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.35
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582116.0028160.270791
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.512
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.45
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582117.370810.043680
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.512
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.55
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582118.8629530.312499
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.512
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.65
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582120.1999760.558294
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.512
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.75
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582121.4786660.221580
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.512
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.85
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582122.75200410.408598
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.512
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.95
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582124.12884880.795348
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.488
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.65
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582125.2606770.106026
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.488
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.75
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582126.2994840.195138
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.488
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.85
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582127.6510960.180091
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.488
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.95
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582128.8934180.120952
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.488
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.05
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582129.92217020.114044
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.488
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.15
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582131.05966690.248340
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.488
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.25
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582132.2132660.132258
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.488
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.35
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582133.1293890.756615
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.488
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.45
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582134.16946890.152016
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.488
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.55
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582135.1816080.472741
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.488
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.65
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582136.29398920.944001
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.488
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.75
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582137.40160420.723324
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.488
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.85
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582138.6038940.399128
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.488
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.95
# Dataset generated at: /Volumes/SSD01/data.nosync16b/1586582139.91595220.466574
# Fisher element ( 0 ,  0 ), ( 0 ,  0 ) calculated...
# Fisher element ( 0 ,  1 ), ( 1 ,  0 ) calculated...
# Fisher element ( 0 ,  2 ), ( 2 ,  0 ) calculated...
# Fisher element ( 0 ,  3 ), ( 3 ,  0 ) calculated...
# Fisher element ( 0 ,  4 ), ( 4 ,  0 ) calculated...
# Fisher element ( 0 ,  5 ), ( 5 ,  0 ) calculated...
# Fisher element ( 0 ,  6 ), ( 6 ,  0 ) calculated...
# Fisher element ( 0 ,  7 ), ( 7 ,  0 ) calculated...
# Fisher element ( 0 ,  8 ), ( 8 ,  0 ) calculated...
# Fisher element ( 0 ,  9 ), ( 9 ,  0 ) calculated...
# Fisher element ( 0 ,  10 ), ( 10 ,  0 ) calculated...
# Fisher element ( 1 ,  1 ), ( 1 ,  1 ) calculated...
# Fisher element ( 1 ,  2 ), ( 2 ,  1 ) calculated...
# Fisher element ( 1 ,  3 ), ( 3 ,  1 ) calculated...
# Fisher element ( 1 ,  4 ), ( 4 ,  1 ) calculated...
# Fisher element ( 1 ,  5 ), ( 5 ,  1 ) calculated...
# Fisher element ( 1 ,  6 ), ( 6 ,  1 ) calculated...
# Fisher element ( 1 ,  7 ), ( 7 ,  1 ) calculated...
# Fisher element ( 1 ,  8 ), ( 8 ,  1 ) calculated...
# Fisher element ( 1 ,  9 ), ( 9 ,  1 ) calculated...
# Fisher element ( 1 ,  10 ), ( 10 ,  1 ) calculated...
# Fisher element ( 2 ,  2 ), ( 2 ,  2 ) calculated...
# Fisher element ( 2 ,  3 ), ( 3 ,  2 ) calculated...
# Fisher element ( 2 ,  4 ), ( 4 ,  2 ) calculated...
# Fisher element ( 2 ,  5 ), ( 5 ,  2 ) calculated...
# Fisher element ( 2 ,  6 ), ( 6 ,  2 ) calculated...
# Fisher element ( 2 ,  7 ), ( 7 ,  2 ) calculated...
# Fisher element ( 2 ,  8 ), ( 8 ,  2 ) calculated...
# Fisher element ( 2 ,  9 ), ( 9 ,  2 ) calculated...
# Fisher element ( 2 ,  10 ), ( 10 ,  2 ) calculated...
# Fisher element ( 3 ,  3 ), ( 3 ,  3 ) calculated...
# Fisher element ( 3 ,  4 ), ( 4 ,  3 ) calculated...
# Fisher element ( 3 ,  5 ), ( 5 ,  3 ) calculated...
# Fisher element ( 3 ,  6 ), ( 6 ,  3 ) calculated...
# Fisher element ( 3 ,  7 ), ( 7 ,  3 ) calculated...
# Fisher element ( 3 ,  8 ), ( 8 ,  3 ) calculated...
# Fisher element ( 3 ,  9 ), ( 9 ,  3 ) calculated...
# Fisher element ( 3 ,  10 ), ( 10 ,  3 ) calculated...
# Fisher element ( 4 ,  4 ), ( 4 ,  4 ) calculated...
# Fisher element ( 4 ,  5 ), ( 5 ,  4 ) calculated...
# Fisher element ( 4 ,  6 ), ( 6 ,  4 ) calculated...
# Fisher element ( 4 ,  7 ), ( 7 ,  4 ) calculated...
# Fisher element ( 4 ,  8 ), ( 8 ,  4 ) calculated...
# Fisher element ( 4 ,  9 ), ( 9 ,  4 ) calculated...
# Fisher element ( 4 ,  10 ), ( 10 ,  4 ) calculated...
# Fisher element ( 5 ,  5 ), ( 5 ,  5 ) calculated...
# Fisher element ( 5 ,  6 ), ( 6 ,  5 ) calculated...
# Fisher element ( 5 ,  7 ), ( 7 ,  5 ) calculated...
# Fisher element ( 5 ,  8 ), ( 8 ,  5 ) calculated...
# Fisher element ( 5 ,  9 ), ( 9 ,  5 ) calculated...
# Fisher element ( 5 ,  10 ), ( 10 ,  5 ) calculated...
# Fisher element ( 6 ,  6 ), ( 6 ,  6 ) calculated...
# Fisher element ( 6 ,  7 ), ( 7 ,  6 ) calculated...
# Fisher element ( 6 ,  8 ), ( 8 ,  6 ) calculated...
# Fisher element ( 6 ,  9 ), ( 9 ,  6 ) calculated...
# Fisher element ( 6 ,  10 ), ( 10 ,  6 ) calculated...
# Fisher element ( 7 ,  7 ), ( 7 ,  7 ) calculated...
# Fisher element ( 7 ,  8 ), ( 8 ,  7 ) calculated...
# Fisher element ( 7 ,  9 ), ( 9 ,  7 ) calculated...
# Fisher element ( 7 ,  10 ), ( 10 ,  7 ) calculated...
# Fisher element ( 8 ,  8 ), ( 8 ,  8 ) calculated...
# Fisher element ( 8 ,  9 ), ( 9 ,  8 ) calculated...
# Fisher element ( 8 ,  10 ), ( 10 ,  8 ) calculated...
# Fisher element ( 9 ,  9 ), ( 9 ,  9 ) calculated...
# Fisher element ( 9 ,  10 ), ( 10 ,  9 ) calculated...
# Fisher element ( 10 ,  10 ), ( 10 ,  10 ) calculated...
# Relic Forecast  0  complete...

# %%
dill.load_session(os.path.join(ps16_resultsdir, 'ps16b.db'))

# %%
ps16_forecastset[0].spectra_mid[0].datadirectory

# %%
np.savetxt("/Users/nicholasdeporzio/Desktop/k_2.txt", ps16_forecastset[0].k_table[0], delimiter='\t')
np.savetxt("/Users/nicholasdeporzio/Desktop/db_2.txt", ps16_forecastset[0].spectra_mid[0].b_interp_table, delimiter='\t')
np.savetxt("/Users/nicholasdeporzio/Desktop/dcdm_2.txt", ps16_forecastset[0].spectra_mid[0].cdm_interp_table, delimiter='\t')
np.savetxt("/Users/nicholasdeporzio/Desktop/Pg_2.txt", ps16_forecastset[0].Pg[0, :, 20], delimiter='\t')
np.savetxt("/Users/nicholasdeporzio/Desktop/Pm_2.txt", ps16_forecastset[0].Pm[0], delimiter='\t')

# %%
plt.figure(figsize=(15,7.5))

plt.loglog(ps16_forecastset[0].k_table[0], ps16_forecastset[0].Pg[0, :, 20], label=r"$P_g$, $g_\chi$=1.5", linestyle='solid')







plt.title(r"DESI, z=0.65, $\mu=0$, m=0.2[eV]")
plt.xlabel(r"$k$ [Mpc$^{-1}$]", fontsize=24)
plt.ylabel(r"$P_g$", fontsize=24)
plt.legend(fontsize=18, loc='lower left')
plt.tick_params(axis='x', which='minttor')
plt.grid(True, which='minor')
plt.savefig("/Users/nicholasdeporzio/Desktop/testing/plotA19b.png")
plt.show()
