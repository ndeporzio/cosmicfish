# %%
import os
import shutil
import numpy as np
import pandas as pd
import seaborn as sns 
import cosmicfish as cf 
import matplotlib.pyplot as plt
import dill


# Instruct pyplot to use seaborn 
sns.set()

# Set project, data, CLASS directories 
projectdir = cf.correct_path("/Volumes/SSD01/")
datastore = cf.correct_path("/Volumes/SSD01/data.nosync16a/")
classpath = os.path.join("/Users/nicholasdeporzio/Desktop/cfworkspace/class2")

# Specify resolution of numerical integrals
derivative_step = 0.008 # How much to vary parameter to calculate numerical derivative
mu_integral_step = 0.05 # For calculating numerical integral wrt mu between -1 and 1 

# Generate output paths  
ps16_resultsdir = os.path.join(projectdir, 'results', 'ps16a')
cf.makedirectory(ps16_resultsdir)

# Linda Fiducial Cosmology 
ps16_fid = {
        "A_s" : 2.2321e-9, 
        "n_s" : 0.967,
        "omega_b" : 0.02226,
        "omega_cdm" : 0.1127,
        "tau_reio" : 0.0598,
        "h" : 0.701,
        "T_cmb" : 2.726, # Units [K]
        "N_ncdm" : 1., 
        "deg_ncdm" : 1.1,
        "T_ncdm" : (0.9052/2.726), # Units [T_cmb]. 
        "m_ncdm" : 0.0328, # Units [eV]
        "b0" : 1.0, 
        "beta0" : 1.7, 
        "beta1" : 1.0,
        "alphak2" : 1.0,
        "sigma_fog_0" : 250000, #Units [m s^-2]
        "N_eff" : 3.046, #We allow relativistic neutrinos in addition to our DM relic
        "relic_vary" : "N_ncdm" # Fix T_ncdm or m_ncdm 
        }

# EUCLID Parameters
z_table = np.array([0.65, 0.75, 0.85, 0.95, 1.05, 1.15, 1.25, 1.35, 1.45, 1.55, 1.65, 1.75, 1.85, 1.95])
dNdz = np.array([2434.280, 4364.812, 4728.559, 4825.798, 4728.797, 4507.625, 4269.851, 3720.657, 3104.309, 
    2308.975, 1514.831, 1474.707, 893.716, 497.613])
skycover = 0.3636 # Sky coverage of survey in fraction

# Run Fisher Forecast
#masses = np.append(np.array([0.001, 0.01]), np.geomspace(0.1, 22.0, 25))
masses = np.array([0.2])

omegacdm_set = ps16_fid['omega_cdm'] - ps16_fid["N_ncdm"]*((masses/cf.NEUTRINO_SCALE_FACTOR)*np.power(ps16_fid['T_ncdm']*2.726 / 1.95, 3.))                                     
ps16_fiducialset = [dict(ps16_fid, **{'m_ncdm' : masses[midx], 'omega_cdm' : omegacdm_set[midx]}) 
               for midx, mval in enumerate(masses)]

# %%
ps16_forecastset = [cf.forecast(
    classpath, 
    datastore, 
    'relic', 
    fidval, 
    z_table, 
    "EUCLID",
    dNdz, 
    fsky=skycover, 
    dstep=derivative_step,
    RSD=True,
    FOG=True,
    AP=True,
    COV=True) for fididx, fidval in enumerate(ps16_fiducialset)]
for fidx, fcst in enumerate(ps16_forecastset): 
    fcst.gen_pm()
    fcst.gen_fisher(
        fisher_order=[
            'omega_b',                                    
            'omega_cdm',                                  
            'n_s',                                        
            'A_s',                                        
            'tau_reio',                                   
            'h',                                                                             
            'N_ncdm',                                 
            'sigma_fog',                                   
            'beta0',
            'beta1',
            'alpha_k2'],
        mu_step=mu_integral_step, 
        skipgen=False)
    print("Relic Forecast ", fidx, " complete...")
    dill.dump_session(os.path.join(ps16_resultsdir, 'ps16a.db'))
# Out:
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.65
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586581968.83486580.574412
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.75
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586581969.8281880.602714
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.85
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586581970.9334050.660931
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.95
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586581972.07143190.966630
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.05
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586581973.02117090.222040
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.15
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586581974.01594280.034456
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.25
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586581975.28548880.858052
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.35
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586581976.7222380.777066
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.45
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586581978.1155480.045719
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.55
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586581978.97232320.772282
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.65
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586581980.0029280.803849
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.75
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586581981.5955540.826318
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.85
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586581982.4346660.842149
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.95
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586581983.2890.238575
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02243808
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.65
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586581985.0230310.413414
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02243808
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.75
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586581985.9024030.336954
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02243808
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.85
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586581987.1671180.733948
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02243808
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.95
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586581988.0987480.983072
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02243808
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.05
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586581989.1634690.606328
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02243808
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.15
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586581990.5689660.643946
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02243808
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.25
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586581991.9231250.295328
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02243808
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.35
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586581993.08821820.146040
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02243808
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.45
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586581994.0104840.183058
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02243808
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.55
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586581995.4418170.631502
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02243808
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.65
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586581996.30579610.053122
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02243808
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.75
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586581997.35613580.455898
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02243808
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.85
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586581998.57057790.828339
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02243808
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.95
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586581999.5668280.091927
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.022081919999999998
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.65
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582000.95549320.067727
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.022081919999999998
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.75
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582002.3345180.478767
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.022081919999999998
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.85
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582003.4222490.762681
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.022081919999999998
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.95
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582004.7007250.093412
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.022081919999999998
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.05
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582005.592310.222602
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.022081919999999998
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.15
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582007.1780120.105461
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.022081919999999998
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.25
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582008.4004320.848181
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.022081919999999998
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.35
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582009.5219150.087702
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.022081919999999998
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.45
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582010.6386260.121985
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.022081919999999998
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.55
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582011.54927590.412096
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.022081919999999998
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.65
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582012.9210210.729472
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.022081919999999998
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.75
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582014.5356170.492119
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.022081919999999998
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.85
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582016.19304080.463713
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.022081919999999998
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.95
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582017.25106620.104322
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.1133850869410217
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.65
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582018.8759410.796168
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.1133850869410217
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.75
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582020.03974820.250210
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.1133850869410217
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.85
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582021.5409410.824114
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.1133850869410217
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.95
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582022.7391760.553080
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.1133850869410217
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.05
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582024.28503080.021780
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.1133850869410217
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.15
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582025.6371160.093526
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.1133850869410217
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.25
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582028.05339380.509587
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.1133850869410217
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.35
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582029.8935550.198302
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.1133850869410217
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.45
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582031.4115610.226561
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.1133850869410217
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.55
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582032.6709860.844289
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.1133850869410217
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.65
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582034.26223680.853260
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.1133850869410217
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.75
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582035.51970310.128252
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.1133850869410217
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.85
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582037.2399990.359114
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.1133850869410217
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.95
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582038.7092790.777119
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11158532365624357
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.65
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582040.17910980.463958
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11158532365624357
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.75
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582041.7905950.313182
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11158532365624357
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.85
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582043.75171520.495078
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11158532365624357
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.95
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582044.722230.351840
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11158532365624357
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.05
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582046.11396880.917148
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11158532365624357
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.15
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582047.5830920.947748
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11158532365624357
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.25
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582049.4155330.489861
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11158532365624357
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.35
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582050.72739890.090103
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11158532365624357
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.45
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582051.98461320.203602
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11158532365624357
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.55
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582053.7101510.580407
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11158532365624357
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.65
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582054.9039150.479012
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11158532365624357
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.75
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582056.406450.972316
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11158532365624357
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.85
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582057.74688890.295669
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11158532365624357
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.95
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582059.2070550.763659
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.706608
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.65
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582060.6707970.761790
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.706608
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.75
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582062.0651840.465740
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.706608
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.85
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582063.47893880.802038
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.706608
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.95
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582064.9131760.286507
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.706608
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.05
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582066.2112720.554509
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.706608
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.15
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582067.6817460.790241
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.706608
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.25
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582068.86248090.211101
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.706608
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.35
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582070.5546670.857788
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.706608
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.45
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582072.03391310.923878
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.706608
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.55
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582073.4813890.602551
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.706608
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.65
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582074.8095290.889548
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.706608
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.75
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582076.3517120.279474
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.706608
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.85
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582078.0915630.786240
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.706608
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.95
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582080.1683490.038791
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.6953919999999999
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.65
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582081.2247490.138788
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.6953919999999999
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.75
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582082.3321690.426580
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.6953919999999999
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.85
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582083.5916280.814465
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.6953919999999999
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.95
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582084.6646810.966744
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.6953919999999999
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.05
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582086.1775060.297867
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.6953919999999999
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.15
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582087.4716480.063763
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.6953919999999999
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.25
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582088.65519210.599937
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.6953919999999999
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.35
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582089.49709490.572946
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.6953919999999999
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.45
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582090.89487890.439675
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.6953919999999999
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.55
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582092.1750180.520427
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.6953919999999999
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.65
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582093.13949580.771998
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.6953919999999999
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.75
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582094.44730110.805955
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.6953919999999999
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.85
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582095.47031710.724023
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.6953919999999999
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.95
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582096.49900910.791638
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0602784
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.65
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582097.7159810.823858
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0602784
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.75
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582098.9634160.930644
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0602784
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.85
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582099.9534720.443443
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0602784
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.95
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582100.8210270.852208
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0602784
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.05
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582102.22635480.116659
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0602784
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.15
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582103.2236770.254249
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0602784
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.25
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582104.6111920.478107
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0602784
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.35
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582105.5680440.488369
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0602784
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.45
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582106.7219140.120337
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0602784
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.55
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582107.8236340.945369
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0602784
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.65
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582108.9827610.321024
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0602784
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.75
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582110.1166270.725291
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0602784
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.85
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582111.7847060.404078
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0602784
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.95
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582112.8677840.935446
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.059321599999999995
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.65
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582113.8179970.276813
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.059321599999999995
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# ...
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.85
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582128.1500570.558881
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.059321599999999995
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.95
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582129.08244780.854896
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1088
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.65
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582130.14500880.063479
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1088
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.75
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582131.3813830.254869
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1088
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.85
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582132.4887070.900172
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1088
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.95
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582133.97252820.505993
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1088
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.05
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582134.9156610.305575
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1088
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.15
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582136.0583350.283008
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1088
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.25
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582137.0556090.931123
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1088
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.35
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582138.3410240.685812
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1088
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.45
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582139.4682040.092098
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1088
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.55
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582140.5580030.177686
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1088
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.65
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582141.475570.699751
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1088
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.75
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582142.3951640.671327
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1088
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.85
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582143.2393470.450097
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.1088
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.95
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582144.2634960.411613
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.0912000000000002
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.65
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582145.1010850.459751
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.0912000000000002
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.75
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582145.9803090.153476
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.0912000000000002
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.85
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582146.81218310.672388
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.0912000000000002
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.95
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582147.6293290.461551
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.0912000000000002
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.05
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582148.4769410.782591
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.0912000000000002
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.15
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582149.2885020.358051
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.0912000000000002
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.25
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582150.0952480.986774
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.0912000000000002
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.35
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582150.9299230.028480
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.0912000000000002
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.45
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582151.8596550.769218
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.0912000000000002
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.55
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582152.80670.776821
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.0912000000000002
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.65
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582153.7337230.124741
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.0912000000000002
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.75
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582154.6067230.278227
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.0912000000000002
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.85
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582155.5198020.702219
# #A_s-->A_s = 2.2321e-09
# #n_s-->n_s = 0.967
# #omega_b-->omega_b = 0.02226
# #omega_cdm-->omega_cdm = 0.11248520529863264
# #tau_reio-->tau_reio = 0.0598
# #h-->h = 0.701
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #deg_ncdm-->deg_ncdm = 1.0912000000000002
# #T_ncdm-->T_ncdm = 0.33206162876008805
# #m_ncdm-->m_ncdm = 0.2
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.95
# Dataset generated at: /Volumes/SSD01/data.nosync16a/1586582156.498990.819481
# Fisher element ( 0 ,  0 ), ( 0 ,  0 ) calculated...
# Fisher element ( 0 ,  1 ), ( 1 ,  0 ) calculated...
# Fisher element ( 0 ,  2 ), ( 2 ,  0 ) calculated...
# Fisher element ( 0 ,  3 ), ( 3 ,  0 ) calculated...
# Fisher element ( 0 ,  4 ), ( 4 ,  0 ) calculated...
# Fisher element ( 0 ,  5 ), ( 5 ,  0 ) calculated...
# Fisher element ( 0 ,  6 ), ( 6 ,  0 ) calculated...
# Fisher element ( 0 ,  7 ), ( 7 ,  0 ) calculated...
# Fisher element ( 0 ,  8 ), ( 8 ,  0 ) calculated...
# Fisher element ( 0 ,  9 ), ( 9 ,  0 ) calculated...
# Fisher element ( 0 ,  10 ), ( 10 ,  0 ) calculated...
# Fisher element ( 1 ,  1 ), ( 1 ,  1 ) calculated...
# Fisher element ( 1 ,  2 ), ( 2 ,  1 ) calculated...
# Fisher element ( 1 ,  3 ), ( 3 ,  1 ) calculated...
# Fisher element ( 1 ,  4 ), ( 4 ,  1 ) calculated...
# Fisher element ( 1 ,  5 ), ( 5 ,  1 ) calculated...
# Fisher element ( 1 ,  6 ), ( 6 ,  1 ) calculated...
# Fisher element ( 1 ,  7 ), ( 7 ,  1 ) calculated...
# Fisher element ( 1 ,  8 ), ( 8 ,  1 ) calculated...
# Fisher element ( 1 ,  9 ), ( 9 ,  1 ) calculated...
# Fisher element ( 1 ,  10 ), ( 10 ,  1 ) calculated...
# Fisher element ( 2 ,  2 ), ( 2 ,  2 ) calculated...
# Fisher element ( 2 ,  3 ), ( 3 ,  2 ) calculated...
# Fisher element ( 2 ,  4 ), ( 4 ,  2 ) calculated...
# Fisher element ( 2 ,  5 ), ( 5 ,  2 ) calculated...
# Fisher element ( 2 ,  6 ), ( 6 ,  2 ) calculated...
# Fisher element ( 2 ,  7 ), ( 7 ,  2 ) calculated...
# Fisher element ( 2 ,  8 ), ( 8 ,  2 ) calculated...
# Fisher element ( 2 ,  9 ), ( 9 ,  2 ) calculated...
# Fisher element ( 2 ,  10 ), ( 10 ,  2 ) calculated...
# Fisher element ( 3 ,  3 ), ( 3 ,  3 ) calculated...
# Fisher element ( 3 ,  4 ), ( 4 ,  3 ) calculated...
# Fisher element ( 3 ,  5 ), ( 5 ,  3 ) calculated...
# Fisher element ( 3 ,  6 ), ( 6 ,  3 ) calculated...
# Fisher element ( 3 ,  7 ), ( 7 ,  3 ) calculated...
# Fisher element ( 3 ,  8 ), ( 8 ,  3 ) calculated...
# Fisher element ( 3 ,  9 ), ( 9 ,  3 ) calculated...
# Fisher element ( 3 ,  10 ), ( 10 ,  3 ) calculated...
# Fisher element ( 4 ,  4 ), ( 4 ,  4 ) calculated...
# Fisher element ( 4 ,  5 ), ( 5 ,  4 ) calculated...
# Fisher element ( 4 ,  6 ), ( 6 ,  4 ) calculated...
# Fisher element ( 4 ,  7 ), ( 7 ,  4 ) calculated...
# Fisher element ( 4 ,  8 ), ( 8 ,  4 ) calculated...
# Fisher element ( 4 ,  9 ), ( 9 ,  4 ) calculated...
# Fisher element ( 4 ,  10 ), ( 10 ,  4 ) calculated...
# Fisher element ( 5 ,  5 ), ( 5 ,  5 ) calculated...
# Fisher element ( 5 ,  6 ), ( 6 ,  5 ) calculated...
# Fisher element ( 5 ,  7 ), ( 7 ,  5 ) calculated...
# Fisher element ( 5 ,  8 ), ( 8 ,  5 ) calculated...
# Fisher element ( 5 ,  9 ), ( 9 ,  5 ) calculated...
# Fisher element ( 5 ,  10 ), ( 10 ,  5 ) calculated...
# Fisher element ( 6 ,  6 ), ( 6 ,  6 ) calculated...
# Fisher element ( 6 ,  7 ), ( 7 ,  6 ) calculated...
# Fisher element ( 6 ,  8 ), ( 8 ,  6 ) calculated...
# Fisher element ( 6 ,  9 ), ( 9 ,  6 ) calculated...
# Fisher element ( 6 ,  10 ), ( 10 ,  6 ) calculated...
# Fisher element ( 7 ,  7 ), ( 7 ,  7 ) calculated...
# Fisher element ( 7 ,  8 ), ( 8 ,  7 ) calculated...
# Fisher element ( 7 ,  9 ), ( 9 ,  7 ) calculated...
# Fisher element ( 7 ,  10 ), ( 10 ,  7 ) calculated...
# Fisher element ( 8 ,  8 ), ( 8 ,  8 ) calculated...
# Fisher element ( 8 ,  9 ), ( 9 ,  8 ) calculated...
# Fisher element ( 8 ,  10 ), ( 10 ,  8 ) calculated...
# Fisher element ( 9 ,  9 ), ( 9 ,  9 ) calculated...
# Fisher element ( 9 ,  10 ), ( 10 ,  9 ) calculated...
# Fisher element ( 10 ,  10 ), ( 10 ,  10 ) calculated...
# Relic Forecast  0  complete...

# %%
dill.load_session(os.path.join(ps16_resultsdir, 'ps16a.db'))

# %%
np.savetxt("/Users/nicholasdeporzio/Desktop/k_1.txt", ps16_forecastset[0].k_table[0], delimiter='\t')
np.savetxt("/Users/nicholasdeporzio/Desktop/db_1.txt", ps16_forecastset[0].spectra_mid[0].b_interp_table, delimiter='\t')
np.savetxt("/Users/nicholasdeporzio/Desktop/dcdm_1.txt", ps16_forecastset[0].spectra_mid[0].cdm_interp_table, delimiter='\t')
np.savetxt("/Users/nicholasdeporzio/Desktop/Pg_1.txt", ps16_forecastset[0].Pg[0, :, 20], delimiter='\t')
np.savetxt("/Users/nicholasdeporzio/Desktop/Pm_1.txt", ps16_forecastset[0].Pm[0], delimiter='\t')

# %%
plt.figure(figsize=(15,7.5))

plt.semilogy(ps16_forecastset[0].k_table[0], ps16_forecastset[0].RSD[0, :, 20], label=r"$P_g$, $g_\chi$=1.1", linestyle='solid')
plt.title(r"DESI, z=0.65, $\mu=0$, m=0.2[eV]")
plt.xlabel(r"$k$ [Mpc$^{-1}$]", fontsize=24)
plt.ylabel(r"$P_m$", fontsize=24)
plt.legend(fontsize=18, loc='lower left')
plt.tick_params(axis='x', which='minttor')
plt.grid(True, which='minor')
plt.savefig("/Users/nicholasdeporzio/Desktop/testing/plotA19a.png")
plt.show()

# %%
ps16_forecastset[0].mu_table[20]
