# %% [markdown]
# # Setup Your Analysis Environment
#
# 1) Choose a directory to house your project in:
# ```
# .../<project-directory>
# ```
#
#
# 2) Create and activate a fresh Python3 virtual environment (we use Python 3.6.8) there if you'd like:
# ```
# $ cd .../<project-directory>
# $ python -m virtualenv env
# $ source env/bin/activate
# ```
#
# 3) Download the `cosmicfish` package from Git:
# ```
# $ git clone git@github.com:ndeporzio/cosmicfish.git
# ```
#
# 4) Install the `cosmicfish` package. Note that its dependencies will install automatically.
# ```
# $ cd cosmicfish
# $ pip install .
# ```
#
# 5) Launch Jupyter and open `tutorial.ipynb` notebook using Jupyter browser
# ```
# $ jupyter notebook
# ```
#
# 6) Create a data folder where the analysis can store spectrum data. This can be anywhere you'd like - you'll specify the path below.
# ```
# $ mkdir <project-directory>/data
# ```
#
# 7) Install and build CLASS (if you don't already have a build). Note the `cosmicfish` package includes a method for downloading and installing CLASS for you:
# ```
# $ python
# >>> import cosmicfish as cf
# >>> cf.install_class('<project-directory>/class')
# >>> exit()
# ```

# %% [markdown]
# # Import & Configure _cosmicfish_

# %% [markdown]
# Import the analysis package.

# %%
import cosmicfish as cf

# %% [markdown]
# Import relevant python packages...

# %%
#Import relevant packages
import os
import shutil
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# Other setup steps...

# %%
#Instruct pyplot to use seaborn 
sns.set()

# %% [markdown]
# Specify the paths from the setup of your analysis environment above.

# %%
#Set project, data, CLASS directories 
projectdir = cf.correct_path("~/Desktop/cfworkspace/")
datastore = cf.correct_path("/Volumes/SSD01/datastore/")
classpath = os.path.join(projectdir, "class")

# %% [markdown]
# Specify the granularity of numerical derivatives.

# %%
derivative_step = 0.005 #How much to vary parameter to calculate numerical derivative
mu_integral_step = 0.05 #For calculating numerical integral wrt mu between -1 and 1

# %% [markdown]
# # Specify Fiducial Cosmology

# %% [markdown]
# Here we specify the fiducial cosmology used in our forecasts. For light relic forecasts, we choose whether to vary with respect to the relic mass or the relic temperature, specified by the "relic_fix" parameter. Since we are interested in forecasting errors on T_chi, we choose to vary  T_ncdm.

# %%
relicfid = {
        "A_s" : 2.22e-9, 
        "n_s" : 0.965,
        "omega_b" : 0.02222,
        "omega_cdm" : 0.1120,
        "tau_reio" : 0.06,
        "h" : 0.70,
        "T_cmb" : 2.726, # Units [K]
        "N_ncdm" : 1., 
        "T_ncdm" : (1.50/2.726), # Units [T_cmb]. We choose this temp, 1.5 K, because that's what our CMBS4 priors are calculated at.
        "m_ncdm" : 0.03, # Units [eV]
        "b0" : 1.0, 
        "alphak2" : 1.0,
        "sigma_fog_0" : 250000, #Units [m s^-2]
        "N_eff" : 3.046, #We allow relativistic neutrinos in addition to our DM relic
        "relic_fix" : "m_ncdm" # Fix T_ncdm or m_ncdm 
        }

# %% [markdown]
# # Specify Experiment Observational Parameters

# %% [markdown]
# The experimental redshift configuration and noise is specified here.

# %%
#Specify redshift bins, noise per bin, and sky coverage

# EUCLID values
#z_table = np.arange(0.65, 2.05, 0.1)
#dNdz = np.array([2434.280, 4364.812, 4728.559, 4825.798, 4728.797, 4507.625, 4269.851, 3720.657, 3104.309, 
#    2308.975, 1514.831, 1474.707, 893.716, 497.613])
#skycover = 0.3636 # Sky coverage of survey in fraction

# DESI Parameters
z_table = np.arange(0.65, 1.85, 0.1)
dNdz = np.array([309., 2269., 1923., 2094., 1441., 1353., 1337., 523., 466., 329., 126., 0., 0.])
skycover = 14000. # Sky coverage of survey in degrees^2

# %% [markdown]
# # Demonstrate Convergence at one Fiducial Mass

# %% [markdown]
# Before running the forecast, we want to ensure our cosmological parameters are well converged about the points we are interested in using to calculate Fisher matrices. To do so, we can use the `convergence` class of `cosmicfish`.
#
# We pass to `convergence` some fiducial cosmology, and then it will vary the parameters of that fiducial cosmology by step sizes specified by the user and compute the corresponding power spectrum derivatives.
#
# All 'varyfactors' are computed relative to the fiducial cosmology. That is:
#
# dtheta = varyfactor * theta_fiducial
#
# **WARNING: This process takes a considerable amount of time (~5 mins per varyfactor w/o prexisting data). Only run when you need to.**

# %%
relicconvergencetest = cf.convergence(
    classpath, # Path to CLASS installation
    datastore, # Path to directory holding CLASS output data
    'relic', # 'relic' or 'neutrino' forecasting scheme 
    relicfid, # The fiducial cosmology 
    z_table, # Redshift steps in observation
    dNdz, # Redshift noise in observation
    fisher_order=[
            'omega_b',                                    
            'omega_cdm',                                  
            'n_s',                                        
            'A_s',                                        
            'tau_reio',                                   
            'h',                                          
            #'M_ncdm',                                    
            'T_ncdm',                                 
            'sigma_fog',                                   
            'b0',                                         
            'alpha_k2'],
    fcoverage_deg=14000, # Sky coverage in observation
    RSD=True, # Use RSD correction to Pm
    FOG=True, # Use FOG correction to Pm
    AP=True, # Use AP correction to PM
    COV=True, #Use AP Change of Variables correction to PM
    mu_step=mu_integral_step,
    varyfactors=[0.001, 0.003, 0.005, 0.007, 0.009] # Relative factors used to compute convergence
    )
relicconvergencetest.gen_all_plots() # Display convergence plots
# Out:
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.02222
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.65
# Dataset generated at: /Volumes/SSD01/datastore/1576089446.3635120.178246
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.02222
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.75
# Dataset generated at: /Volumes/SSD01/datastore/1576089448.837630.077671
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.02222
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.85
# Dataset generated at: /Volumes/SSD01/datastore/1576089451.53979020.846862
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.02222
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.95
# Dataset generated at: /Volumes/SSD01/datastore/1576089453.7003140.394610
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.02222
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.0499999999999998
# Dataset generated at: /Volumes/SSD01/datastore/1576089456.05221990.002577
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.02222
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.15
# Dataset generated at: /Volumes/SSD01/datastore/1576089458.5492430.689089
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.02222
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.25
# Dataset generated at: /Volumes/SSD01/datastore/1576089460.7042950.706344
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.02222
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.3499999999999999
# Dataset generated at: /Volumes/SSD01/datastore/1576089462.8526180.595588
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.02222
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.4499999999999997
# Dataset generated at: /Volumes/SSD01/datastore/1576089464.999340.403396
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.02222
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.5499999999999998
# Dataset generated at: /Volumes/SSD01/datastore/1576089467.1172590.719717
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.02222
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.65
# Dataset generated at: /Volumes/SSD01/datastore/1576089469.28570910.866465
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.02222
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.7499999999999996
# Dataset generated at: /Volumes/SSD01/datastore/1576089471.9322350.586566
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.02222
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.8499999999999996
# Dataset generated at: /Volumes/SSD01/datastore/1576089474.29235890.787507
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.022242219999999997
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.65
# Dataset generated at: /Volumes/SSD01/datastore/1576089476.7604860.179414
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.022242219999999997
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.75
# Dataset generated at: /Volumes/SSD01/datastore/1576089479.0491970.979617
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.022242219999999997
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.85
# Dataset generated at: /Volumes/SSD01/datastore/1576089481.15688920.085063
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.022242219999999997
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.95
# Dataset generated at: /Volumes/SSD01/datastore/1576089483.3047970.968833
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.022242219999999997
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.0499999999999998
# Dataset generated at: /Volumes/SSD01/datastore/1576089485.4394520.453383
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.022242219999999997
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.15
# Dataset generated at: /Volumes/SSD01/datastore/1576089487.5497030.590827
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.022242219999999997
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.25
# Dataset generated at: /Volumes/SSD01/datastore/1576089489.6446670.581514
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.022242219999999997
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.3499999999999999
# Dataset generated at: /Volumes/SSD01/datastore/1576089491.74790720.724989
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.022242219999999997
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.4499999999999997
# Dataset generated at: /Volumes/SSD01/datastore/1576089493.9530990.227983
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.022242219999999997
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.5499999999999998
# Dataset generated at: /Volumes/SSD01/datastore/1576089496.0706580.684409
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.022242219999999997
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.65
# Dataset generated at: /Volumes/SSD01/datastore/1576089498.1810140.000675
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.022242219999999997
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.7499999999999996
# Dataset generated at: /Volumes/SSD01/datastore/1576089500.28080420.049779
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.022242219999999997
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.8499999999999996
# Dataset generated at: /Volumes/SSD01/datastore/1576089502.4632330.333851
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.02219778
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.65
# Dataset generated at: /Volumes/SSD01/datastore/1576089504.5506660.986002
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.02219778
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.75
# Dataset generated at: /Volumes/SSD01/datastore/1576089506.8397840.017384
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.02219778
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.85
# Dataset generated at: /Volumes/SSD01/datastore/1576089509.0715360.858517
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.02219778
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 0.95
# Dataset generated at: /Volumes/SSD01/datastore/1576089511.21331790.693021
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.02219778
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.0499999999999998
# Dataset generated at: /Volumes/SSD01/datastore/1576089513.342130.983133
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.02219778
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.15
# Dataset generated at: /Volumes/SSD01/datastore/1576089515.437940.154575
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.02219778
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.25
# Dataset generated at: /Volumes/SSD01/datastore/1576089517.5522820.571340
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.02219778
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5502567865003668
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.3499999999999999
# Dataset generated at: /Volumes/SSD01/datastore/1576
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.02222
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5497065297138665
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.5499999999999998
# Dataset generated at: /Volumes/SSD01/datastore/1576089745.3485850.906326
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.02222
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5497065297138665
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.65
# Dataset generated at: /Volumes/SSD01/datastore/1576089747.487030.590438
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.02222
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5497065297138665
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.7499999999999996
# Dataset generated at: /Volumes/SSD01/datastore/1576089749.66189380.637720
# #A_s-->A_s = 2.22e-09
# #n_s-->n_s = 0.965
# #omega_b-->omega_b = 0.02222
# #omega_cdm-->omega_cdm = 0.112
# #tau_reio-->tau_reio = 0.06
# #h-->h = 0.7
# #T_cmb-->T_cmb = 2.726
# #N_ncdm-->N_ncdm = 1.0
# #T_ncdm-->T_ncdm = 0.5497065297138665
# #m_ncdm-->m_ncdm = 0.03
# #N_eff-->N_eff = 3.046
# #z_pk-->z_pk = 1.8499999999999996
# Dataset generated at: /Volumes/SSD01/datastore/1576089751.8263380.686561
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-fb5d11ea8d5c> in <module>
#      24     COV=True, #Use AP Change of Variables correction to PM
#      25     mu_step=mu_integral_step,
# ---> 26     varyfactors=[0.001, 0.003, 0.005, 0.007, 0.009] # Relative factors used to compute convergence
#      27     )
#      28 relicconvergencetest.gen_all_plots() # Display convergence plots
#
# ~/Documents/Academic/Research/Projects/cosmicfish/cosmicfish/convergence.py in __init__(self, classdir, datastore, forecast_type, fiducialcosmology, z_steps, dNdz, fisher_order, fsky, fcoverage_deg, RSD, FOG, AP, COV, mu_step, parameters, varyfactors, showplots, saveplots, savepath, plotparams)
#      85                 fisher_order,
#      86                 mu_step=self.mu_step,
# ---> 87                 skipgen=False)
#      88
#      89
#
# ~/Documents/Academic/Research/Projects/cosmicfish/cosmicfish/forecast.py in gen_fisher(self, fisher_order, mu_step, skipgen)
#     792
#     793             for muidx, muval in enumerate(mu_vals):
# --> 794                 self.gen_rsd(muval)
#     795                 self.gen_fog(muval)
#     796                 self.gen_ap()
#
# ~/Documents/Academic/Research/Projects/cosmicfish/cosmicfish/forecast.py in gen_rsd(self, mu)
#     254                         'relic' : relic,
#     255                         'T_ncdm' : self.T_ncdm_fid,
# --> 256                         'delta_L' : self.delta_L_fid}
#     257
#     258             self.RSD = [[cf.rsd(**dict(fiducial, **{'z' : zval, 'k' : kval,
#
# AttributeError: 'forecast' object has no attribute 'delta_L_fid'

# %% [markdown]
# # Run Fisher Forecasts

# %%
masses = np.geomspace(0.1, 10.0, 21) 
omegacdm_set = relicfid['omega_cdm'] - ((masses/cf.NEUTRINO_SCALE_FACTOR)*np.power(1.5 / 1.95, 3.))
                                        
fiducialset = [dict(relicfid, **{'m_ncdm' : masses[midx], 'omega_cdm' : omegacdm_set[midx]}) 
               for midx, mval in enumerate(masses)]
 
forecastset = [cf.forecast(
    classpath, 
    datastore, 
    'relic', 
    fidval, 
    z_table, 
    dNdz, 
    fcoverage_deg=skycover, 
    dstep=derivative_step,
    RSD=True,
    FOG=True,
    AP=True,
    COV=True) for fididx, fidval in enumerate(fiducialset)]

for fidx, fcst in enumerate(forecastset): 
    fcst.gen_pm()
    fcst.gen_fisher(
        fisher_order=[
            'omega_b',                                    
            'omega_cdm',                                  
            'n_s',                                        
            'A_s',                                        
            'tau_reio',                                   
            'h',                                          
            #'M_ncdm',                                    
            'T_ncdm',                                 
            'sigma_fog',                                   
            'b0',                                         
            'alpha_k2'],
        mu_step=mu_integral_step, 
        skipgen=False)
    print("Relic Forecast ", fidx, " complete...")

# %%
inpath = "/Users/nicholasdeporzio/Documents/Academic/Research/Projects/cosmicfish/cosmicfish/priors/CMBS4_Fisher_Relic_"
outpath = "/Users/nicholasdeporzio/Desktop/cfworkspace/results/scienceresults_1K/covariances/"

for fidx, fval in enumerate(forecastset):
    fval.load_cmb_fisher(
        fisher_order=[
            'omega_b',                                    
            'omega_cdm',                                  
            'n_s',                                        
            'A_s',                                        
            'tau_reio',                                   
            'h',                                                                             
            'T_ncdm'],
        fisherpath=inpath+str(fidx+1)+".dat")
    print("CMB Fisher information loaded to forecast " + str(fidx) + "...")
    fval.export_matrices("~/Desktop")
    shutil.move("/Users/nicholasdeporzio/Desktop/inv_cmbfisher.mat", outpath+"cmb/"+"inv_cmbfisher_"+str(fidx+1)+".mat")
    shutil.move("/Users/nicholasdeporzio/Desktop/inv_lssfisher.mat", outpath+"lss/"+"inv_lssfisher_"+str(fidx+1)+".mat")
    shutil.move("/Users/nicholasdeporzio/Desktop/inv_fullfisher.mat", outpath+"full/"+"inv_fullfisher_"+str(fidx+1)+".mat")

# %%
#Save all the LSS/CMB/Full fisher matrices  
for fidx, fcst in enumerate(forecastset):
    name = '/Users/nicholasdeporzio/Desktop/cfworkspace/results/scienceresults_1K/fishers/full/FULL_Fisher_' + str(fidx+1) + '.dat'
    head = 'omega_b \t omega_cdm \t n_s \t A_s \t tau_reio \t h \t T_ncdm \t sigma_fog \t b_0 \t alpha_k2'
    np.savetxt(name, fcst.numpy_full_fisher, delimiter='\t', header=head)

# %%
errors_Tncdm_cmb = [np.sqrt(fval.numpy_cmb_covariance[6,6]) for fidx, fval in enumerate(forecastset)]    
errors_Tncdm_lss = [np.sqrt(fval.numpy_lss_covariance[6,6]) for fidx, fval in enumerate(forecastset)]
errors_Tncdm_full = [np.sqrt(fval.numpy_full_covariance[6,6]) for fidx, fval in enumerate(forecastset)]

plt.figure(figsize=(15,7.5))
plt.semilogx(masses, errors_Tncdm_full, label="CMB+LSS")
plt.semilogx(masses, errors_Tncdm_lss, label="LSS")
plt.semilogx(masses, errors_Tncdm_cmb, label="CMB")
plt.title("Relic Temperature Uncertainty")
plt.xlabel("Relic Mass [eV]")
plt.ylabel(r"$\sigma_T ~[K]$")
plt.legend()
plt.savefig("/Users/nicholasdeporzio/Desktop/results.png")
plt.show()

# %%
import dill
dill.dump_session("/Users/nicholasdeporzio/Desktop/Relic_Science_Plot.db")
